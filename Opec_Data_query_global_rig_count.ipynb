# %%
# some_file.py
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, 'oil_api')
import os
import pandas as pd

# %%
import opec
# Out:
# opec_supply_demand:
# #                Country                                                            2016                 2017                 2018                 1Q19                2Q19                3Q19                4Q19                2019                 1Q20                2Q20                3Q20                4Q20                2020
#      (string)    (string)                                                           (number)             (number)             (number)             (number)            (number)            (number)            (number)            (number)             (number)            (number)            (number)            (number)            (number)
# ...

# %%
glb_rig_count = pd.read_csv('oil_api/opec//data/glb_rig_count.csv')  
oil_liquid_production = pd.read_csv('oil_api/opec//data/oil_liquid_production.csv')  
opec_storage_water = pd.read_csv('oil_api/opec//data/opec_storage_water.csv')

# %%
opec_storage_water = opec_storage_water.drop(opec_storage_water.columns[0], axis=1)
opec_storage_water.head()
# Out:
#                                   _   Country      2017      2018      2019  \
# 0  OECD oil stocks and oil on water       NaN       NaN       NaN       NaN
# 1          Closing stock levels, mb       NaN       NaN       NaN       NaN
# 2            OECD onland commercial       NaN  2859.540  2873.147  2901.695
# 3                               NaN  Americas  1498.320  1543.608  1538.353
# 4                               NaN    Europe   948.008   929.726   972.097
#
#     -      Q417      1Q18      2Q18      3Q18      4Q18      1Q19      2Q19  \
# 0 NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1 NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2 NaN  2859.540  2816.234  2812.406  2865.334  2873.147  2876.651  2935.883
# 3 NaN  1498.320  1470.756  1473.027  1542.864  1543.608  1508.310  1564.778
# 4 NaN   948.008   967.596   951.753   932.803   929.726   988.857   982.194
#
#        3Q19      4Q19
# 0       NaN       NaN
# ...
